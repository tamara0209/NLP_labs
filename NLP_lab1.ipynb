# %%
import string
import nltk
import numpy as np
import torch.functional as F
import torch.nn.functional as F
import pandas as pd
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import re
import torch
from torch.autograd import Variable

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from string import punctuation
from nltk.stem.porter import *
from nltk.stem import WordNetLemmatizer
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

STOPWORDS = set(stopwords.words('english'))

# %%
dataset = pd.read_csv('/Users/ts/Downloads/bbc-text.csv')
dataset.head()
# Out:
#         category                                               text
# 0           tech  tv future in the hands of viewers with home th...
# 1       business  worldcom boss  left books alone  former worldc...
# 2          sport  tigers wary of farrell  gamble  leicester say ...
# 3          sport  yeading face newcastle in fa cup premiership s...
# 4  entertainment  ocean s twelve raids box office ocean s twelve...

# %%
def preprocess_text(text):
    '''Make text lowercase, remove text in square brackets, 
    remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub(r'\[.*?\]', '', text)
    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub(r'\w*\d\w*', '', text)
    # Remove a sentence if it is only one word long
    if len(text) > 2:
        return ' '.join(word for word in text.split() if word not in STOPWORDS)

dataset_clean = pd.DataFrame(dataset.text.apply(lambda x: preprocess_text(x)))

# %%
dataset_clean.head()
# Out:
#                                                 text
# 0  tv future hands viewers home theatre systems p...
# 1  worldcom boss left books alone former worldcom...
# 2  tigers wary farrell gamble leicester say rushe...
# 3  yeading face newcastle fa cup premiership side...
# 4  ocean twelve raids box office ocean twelve cri...

# %%
dataset = pd.read_csv('/Users/ts/Downloads/bbc-text.csv')
dataset = dataset[dataset.category == 'entertainment']
dataset.index = np.arange(len(dataset))
dataset = dataset[:30]
print(dataset.head())
print(len(dataset))
# Out:
#         category                                               text
# 0  entertainment  ocean s twelve raids box office ocean s twelve...
# 1  entertainment  last star wars  not for children  the sixth an...
# 2  entertainment  berlin cheers for anti-nazi film a german movi...
# 3  entertainment  career honour for actor dicaprio actor leonard...
# 4  entertainment  halloween writer debra hill dies screenwriter ...
# 30

# %%
corpus = dataset['text']
print(corpus)
# Out:
# 0     ocean s twelve raids box office ocean s twelve...
# 1     last star wars  not for children  the sixth an...
# 2     berlin cheers for anti-nazi film a german movi...
# 3     career honour for actor dicaprio actor leonard...
# 4     halloween writer debra hill dies screenwriter ...
# 5     celebrities get their skates on former england...
# 6     show over for mtv s the osbournes rock star oz...
# 7     row threatens hendrix museum plan proposals to...
# 8     franz man seeks government help franz ferdinan...
# 9     top of the pops leaves bbc one the bbc s flags...
# 10    controversial film tops festival a controversi...
# 11    cult band kasabian surge forward indie dance b...
# 12    rapper kanye west s shrewd soul us hip-hop sta...
# 13    housewives lift channel 4 ratings the debut of...
# 14    lit idol begins search for author the second p...
# 15    rapper jay-z becomes label boss rap star jay-z...
# 16    berlin hails european cinema organisers say th...
# 17    byrds producer melcher dies at 62 record produ...
# 18    animation charms japan box office oscar-winnin...
# 19    slater to star in broadway play actor christia...
# 20    film production  falls  40% in uk the number o...
# 21    hillbillies singer scoggins dies country and w...
# 22    bennett play takes theatre prizes the history ...
# 23    the comic book genius of stan lee stan lee  th...
# 24    goodrem wins top female mtv prize pop singer d...
# 25    musical treatment for capra film the classic f...
# 26    springer criticises opera musical talk show ho...
# 27    stars gear up for bafta ceremony film stars fr...
# 28    carry on star patsy rowlands dies actress pats...
# 29    grammys honour soul star charles the memory of...
# Name: text, dtype: object

# %%
tokenized_corpus = []
stemmer = PorterStemmer()
for i in range(len(corpus)):
    sentence = preprocess_text(corpus[i])
    tokenized_corpus.append(word_tokenize((sentence)))
print(tokenized_corpus)
# Out:
# [['ocean', 'twelve', 'raids', 'box', 'office', 'ocean', 'twelve', 'crime', 'caper', 'sequel', 'starring', 'george', 'clooney', 'brad', 'pitt', 'julia', 'roberts', 'gone', 'straight', 'number', 'one', 'us', 'box', 'office', 'chart', 'took', '£', 'weekend', 'ticket', 'sales', 'according', 'studio', 'estimates', 'sequel', 'follows', 'master', 'criminals', 'try', 'pull', 'three', 'major', 'heists', 'across', 'europe', 'knocked', 'last', 'week', 'number', 'one', 'national', 'treasure', 'third', 'place', 'wesley', 'snipes', 'blade', 'trinity', 'second', 'taking', '£', 'rounding', 'top', 'five', 'animated', 'fable', 'polar', 'express', 'starring', 'tom', 'hanks', 'festive', 'comedy', 'christmas', 'kranks', 'ocean', 'twelve', 'box', 'office', 'triumph', 'marks', 'fourthbiggest', 'opening', 'december', 'release', 'us', 'three', 'films', 'lord', 'rings', 'trilogy', 'sequel', 'narrowly', 'beat', 'predecessor', 'ocean', 'eleven', 'took', '£', 'opening', 'weekend', '£', 'total', 'remake', 'film', 'starring', 'frank', 'sinatra', 'rat', 'pack', 'ocean', 'eleven', 'directed', 'oscarwinning', 'director', 'steven', 'soderbergh', 'soderbergh', 'returns', 'direct', 'hit', 'sequel', 'reunites', 'clooney', 'pitt', 'roberts', 'matt', 'damon', 'andy', 'garcia', 'elliott', 'gould', 'catherine', 'zetajones', 'joins', 'allstar', 'cast', 'fun', 'good', 'holiday', 'movie', 'said', 'dan', 'fellman', 'president', 'distribution', 'warner', 'bros', 'however', 'us', 'critics', 'less', 'complimentary', '£', 'project', 'los', 'angeles', 'times', 'labelling', 'dispiriting', 'vanity', 'project', 'milder', 'review', 'new', 'york', 'times', 'dubbed', 'sequel', 'unabashedly', 'trivial'], ['last', 'star', 'wars', 'children', 'sixth', 'final', 'star', 'wars', 'movie', 'may', 'suitable', 'young', 'children', 'filmmaker', 'george', 'lucas', 'said', 'told', 'us', 'tv', 'show', 'minutes', 'revenge', 'sith', 'would', 'darkest', 'violent', 'series', 'think', 'would', 'take', 'five', 'sixyearold', 'told', 'cbs', 'programme', 'aired', 'sunday', 'lucas', 'predicted', 'film', 'would', 'get', 'us', 'rating', 'advising', 'parents', 'scenes', 'may', 'unsuitable', 'opens', 'uk', 'us', 'may', 'said', 'expected', 'film', 'would', 'classified', 'roughly', 'equivalent', 'british', 'rating', 'five', 'previous', 'star', 'wars', 'films', 'carried', 'less', 'restrictive', 'pg', 'parental', 'guidance', 'ratings', 'us', 'uk', 'passed', 'u', 'suitable', 'exception', 'attack', 'clones', 'got', 'pg', 'rating', 'revenge', 'sith', 'third', 'prequel', 'original', 'star', 'wars', 'film', 'chronicles', 'transformation', 'heroic', 'anakin', 'skywalker', 'evil', 'darth', 'vader', 'travels', 'helllike', 'planet', 'composed', 'erupting', 'volcanoes', 'molten', 'lava', 'going', 'watch', 'make', 'pact', 'devil', 'lucas', 'said', 'film', 'much', 'dark', 'emotional', 'much', 'tragedy'], ['berlin', 'cheers', 'antinazi', 'film', 'german', 'movie', 'antinazi', 'resistance', 'heroine', 'drawn', 'loud', 'applause', 'berlin', 'film', 'festival', 'sophie', 'scholl', 'final', 'days', 'portrays', 'final', 'days', 'member', 'white', 'rose', 'movement', 'scholl', 'arrested', 'beheaded', 'brother', 'hans', 'distributing', 'leaflets', 'condemning', 'abhorrent', 'tyranny', 'adolf', 'hitler', 'director', 'marc', 'rothemund', 'said', 'feeling', 'responsibility', 'keep', 'legacy', 'scholls', 'going', 'must', 'somehow', 'keep', 'ideas', 'alive', 'added', 'film', 'drew', 'transcripts', 'gestapo', 'interrogations', 'scholl', 'trial', 'preserved', 'archive', 'communist', 'east', 'germany', 'secret', 'police', 'discovery', 'inspiration', 'behind', 'film', 'rothemund', 'worked', 'closely', 'surviving', 'relatives', 'including', 'one', 'scholl', 'sisters', 'ensure', 'historical', 'accuracy', 'film', 'scholl', 'members', 'white', 'rose', 'resistance', 'group', 'first', 'started', 'distributing', 'antinazi', 'leaflets', 'summer', 'arrested', 'dropped', 'leaflets', 'munich', 'university', 'calling', 'day', 'reckoning', 'adolf', 'hitle ...

# %%
import nltk
nltk.download('wordnet')
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to /Users/ts/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/ts/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
vocabulary = []
for sentence in tokenized_corpus:
    for token in sentence:
        if token not in vocabulary:
            vocabulary.append(token)

word2idx = {w: idx for (idx, w) in enumerate(vocabulary)}
idx2word = {idx: w for (idx, w) in enumerate(vocabulary)}

vocabulary_size = len(vocabulary)

# %%
word2idx
# Out:
# {'ocean': 0,
#  'twelve': 1,
#  'raids': 2,
#  'box': 3,
#  'office': 4,
#  'crime': 5,
#  'caper': 6,
#  'sequel': 7,
#  'starring': 8,
#  'george': 9,
#  'clooney': 10,
#  'brad': 11,
#  'pitt': 12,
#  'julia': 13,
#  'roberts': 14,
#  'gone': 15,
#  'straight': 16,
#  'number': 17,
#  'one': 18,
#  'us': 19,
#  'chart': 20,
#  'took': 21,
#  '£': 22,
#  'weekend': 23,
#  'ticket': 24,
#  'sales': 25,
#  'according': 26,
#  'studio': 27,
#  'estimates': 28,
#  'follows': 29,
#  'master': 30,
#  'criminals': 31,
#  'try': 32,
#  'pull': 33,
#  'three': 34,
#  'major': 35,
#  'heists': 36,
#  'across': 37,
#  'europe': 38,
#  'knocked': 39,
#  'last': 40,
#  'week': 41,
#  'national': 42,
#  'treasure': 43,
#  'third': 44,
#  'place': 45,
#  'wesley': 46,
#  'snipes': 47,
#  'blade': 48,
#  'trinity': 49,
#  'second': 50,
#  'taking': 51,
#  'rounding': 52,
#  'top': 53,
#  'five': 54,
#  'animated': 55,
#  'fable': 56,
#  'polar': 57,
#  'express': 58,
#  'tom': 59,
#  'hanks': 60,
#  'festive': 61,
#  'comedy': 62,
#  'christmas': 63,
#  'kranks': 64,
#  'triumph': 65,
#  'marks': 66,
#  'fourthbiggest': 67,
#  'opening': 68,
#  'december': 69,
#  'release': 70,
#  'films': 71,
#  'lord': 72,
#  'rings': 73,
#  'trilogy': 74,
#  'narrowly': 75,
#  'beat': 76,
#  'predecessor': 77,
#  'eleven': 78,
#  'total': 79,
#  'remake': 80,
#  'film': 81,
#  'frank': 82,
#  'sinatra': 83,
#  'rat': 84,
#  'pack': 85,
#  'directed': 86,
#  'oscarwinning': 87,
#  'director': 88,
#  'steven': 89,
#  'soderbergh': 90,
#  'returns': 91,
#  'direct': 92,
#  'hit': 93,
#  'reunites': 94,
#  'matt': 95,
#  'damon': 96,
#  'andy': 97,
#  'garcia': 98,
#  'elliott': 99,
#  'gould': 100,
#  'catherine': 101,
#  'zetajones': 102,
#  'joins': 103,
#  'allstar': 104,
#  'cast': 105,
#  'fun': 106,
#  'good': 107,
#  'holiday': 108,
#  'movie': 109,
#  'said': 110,
#  'dan': 111,
#  'fellman': 112,
#  'president': 113,
#  'distribution': 114,
#  'warner': 115,
#  'bros': 116,
#  'however': 117,
#  'critics': 118,
#  'less': 119,
#  'complimentary': 120,
#  'project': 121,
#  'los': 122,
#  'angeles': 123,
#  'times': 124,
#  'labelling': 125,
#  'dispiriting': 126,
#  'vanity': 127,
#  'milder': 128,
#  'review': 129,
#  'new': 130,
#  'york': 131,
#  'dubbed': 132,
#  'unabashedly': 133,
#  'trivial': 134,
#  'star': 135,
#  'wars': 136,
#  'children': 137,
#  'sixth': 138,
#  'final': 139,
#  'may': 140,
#  'suitable': 141,
#  'young': 142,
#  'filmmaker': 143,
#  'lucas': 144,
#  'told': 145,
#  'tv': 146,
#  'show': 147,
#  'minutes': 148,
#  'revenge': 149,
#  'sith': 150,
#  'would': 151,
#  'darkest': 152,
#  'violent': 153,
#  'series': 154,
#  'think': 155,
#  'take': 156,
#  'sixyearold': 157,
#  'cbs': 158,
#  'programme': 159,
#  'aired': 160,
#  'sunday': 161,
#  'predicted': 162,
#  'get': 163,
#  'rating': 164,
#  'advising': 165,
#  'parents': 166,
#  'scenes': 167,
#  'unsuitable': 168,
#  'opens': 169,
#  'uk': 170,
#  'expected': 171,
#  'classified': 172,
#  'roughly': 173,
#  'equivalent': 174,
#  'british': 175,
#  'previous': 176,
#  'carried': 177,
#  'restrictive': 178,
#  'pg': 179,
#  'parental': 180,
#  'guidance': 181,
#  'ratings': 182,
#  'passed': 183,
#  'u': 184,
#  'exception': 185,
#  'attack': 186,
#  'clones': 187,
#  'got': 188,
#  'prequel': 189,
#  'original': 190,
#  'chronicles': 191,
#  'transformation': 192,
#  'heroic': 193,
#  'anakin': 194,
#  'skywalker': 195,
#  'evil': 196,
#  'darth': 197,
#  'vader': 198,
#  'travels': 199,
#  'helllike': 200,
#  'planet': 201,
#  'composed': 202,
#  'erupting': 203,
#  'volcanoes': 204,
#  'molten': 205,
#  'lava': 206,
#  'going': 207,
#  'watch': 208,
#  'make': 209,
#  'pact': 210,
#  'devil': 211,
#  'much': 212,
#  'dark': 213,
#  'emotional': 214,
#  'tragedy': 215,
#  'berlin': 216,
#  'cheers': 217,
#  'antinazi': 218,
#  'german': 219,
#  'resistance': 220,
#  'heroine': 221,
#  'drawn': 222,
#  'loud': 223,
#  'applause': 224,
#  'festival': 225,
#  'sophie': 226,
#  'scholl': 227,
#  'days': 228,
#  'portrays': 229,
#  'member': 230,
#  'white': 231,
#  'rose': 232,
#  'movement': 233,
#  'arrested': 234,
#  'beheaded': 235,
#  'brother': 236,
#  'hans': 237,
#  'distributing': 238,
#  'leaflets': 239,
#  'condemning': 240,
#  'abhorrent': 241,
#  'tyranny': 242,
#  'adolf': 243,
#  'hitler': 244,
#  'marc': 245,
#  'rothemund': 246,
#  'feeling': 247,
#  'responsibility': 248,
#  'keep': 249,
#  'legacy': 250,
#  'scholls': 251,
#  'must': 252,
#  'somehow': 253,
#  'ideas': 254,
#  'alive': 255,
#  'added': 256,
#  'drew': 257,
#  'transcripts': 258,
#  'gestapo': 259,
#  'interrogations': 260,
#  'trial': 261,
#  'preserved': 262,
#  'archive': 263,
#  'communist': 264,
#  'east': 265,
#  'germany': 266,
#  'secret': 267,
#  'police': 268,
#  'discovery': 269,
#  'inspiration': 270,
#  'behind': 271,
#  'worked': 272,
#  'closely': 273,
#  'surviving': 274,
#  'relatives': 275,
#  'including': 276,
#  'sisters': 277,
#  'ensure': 278,
#  'historical': 279,
#  'accuracy': 280,
#  'members': 281,
#  'group': 282,
#  'first': 283,
#  'started': 284,
#  'summer': 285,
#  'dropped': 286,
#  'munich': 287,
#  'university': 288,
#  'calling': 289,
#  'day': 290,
#  'reckoning': 291,
#  'regime': 292,
#  'focuses': 293,
#  'six': 294,
#  'arrest': 295,
#  'intense': 296,
#  'saw': 297,
#  'initially': 298,
#  'deny': 299,
#  'charges': 300,
#  'ended': 301,
#  'defiant': 302,
#  'appearance': 303,
#  'vying': 304,
#  'prize': 305,
#  'south': 306,
#  'african': 307,
#  'version': 308,
#  'bizet': 309,
#  'tragic': 310,
#  'opera': 311,
#  'carmen': 312,
#  'shot': 313,
#  'cape': 314,
#  'town': 315,
#  'xhosa': 316,
#  'language': 317,
#  'also': 318,
#  'premiered': 319,
#  'entitled': 320,
#  'ucarmen': 321,
#  'ekhayelitsha': 322,
#  'khayelitsha': 323,
#  'township': 324,
#  'story': 325,
#  'set': 326,
#  'performed': 327,
#  'music': 328,
#  'theatre': 329,
#  'troupe': 330,
#  'debut': 331,
#  'performance': 332,
#  'feature': 333,
#  'years': 334,
#  'nominated': 335,
#  'golden': 336,
#  'bear': 337,
#  'award': 338,
#  'career': 339,
#  'honour': 340,
#  'actor': 341,
#  'dicaprio': 342,
#  'leonardo': 343,
#  'exceptional': 344,
#  'honoured': 345,
#  'santa': 346,
#  'barbara': 347,
#  'international': 348,
#  'presented': 349,
#  'martin': 350,
#  'scorsese': 351,
#  'oscarnominated': 352,
#  'aviator': 353,
#  'lifetime': 354,
#  'achievement': 355,
#  'completely': 356,
#  'utterly': 357,
#  'surreal': 358,
#  'given': 359,
#  'old': 360,
#  'almost': 361,
#  'done': 362,
#  'quite': 363,
#  'retrospective': 364,
#  'movies': 365,
#  'shown': 366,
#  'really': 367,
#  'exciting': 368,
#  'love': 369,
#  'want': 370,
#  'rest': 371,
#  'life': 372,
#  'began': 373,
#  'horror': 374,
#  'critters': 375,
#  'moving': 376,
#  'onto': 377,
#  'roles': 378,
#  'basketball': 379,
#  'diaries': 380,
#  'romeo': 381,
#  'juliet': 382,
#  'titanic': 383,
#  'gangs': 384,
#  'created': 385,
#  'commemorate': 386,
#  'california': 387,
#  'anniversary': 388,
#  'coincided': 389,
#  'portrayal': 390,
#  'millionaire': 391,
#  'howard': 392,
#  'hughes': 393,
#  'veteran': 394,
#  'actress': 395,
#  'jane': 396,
#  'russell': 397,
#  'starred': 398,
#  'outlaw': 399,
#  'impressed': 400,
#  'quest': 401,
#  'authenticity': 402,
#  'previously': 403,
#  'discussed': 404,
#  'role': 405,
#  'happy': 406,
#  'came': 407,
#  'cared': 408,
#  'come': 409,
#  'find': 410,
#  'like': 411,
#  'taken': 412,
#  'pole': 413,
#  'position': 414,
#  'year': 415,
#  'oscars': 416,
#  'race': 417,
#  'nominations': 418,
#  'best': 419,
#  'halloween': 420,
#  'writer': 421,
#  'debra': 422,
#  'hill': 423,
#  'dies': 424,
#  'screenwriter': 425,
#  'producer': 426,
#  'known': 427,
#  'work': 428,
#  'classic': 429,
#  'died': 430,
#  'aged': 431,
#  'suffering': 432,
#  'cancer': 433,
#  'cowrote': 434,
#  'jamie': 435,
#  'lee': 436,
#  'curtis': 437,
#  'babysitter': 438,
#  'terrorised': 439,
#  'psychopath': 440,
#  'john': 441,
#  'carpenter': 442,
#  'made': 443,
#  'worldwide': 444,
#  'record': 445,
#  'independent': 446,
#  'time': 447,
#  'escape': 448,
#  'fog': 449,
#  'born': 450,
#  'jersey': 451,
#  'production': 452,
#  'assistant': 453,
#  'way': 454,
#  'ranks': 455,
#  'becoming': 456,
#  'secondunit': 457,
#  'collaborating': 458,
#  'regarded': 459,
#  'many': 460,
#  'pioneering': 461,
#  'woman': 462,
#  'jobs': 463,
#  'commonly': 464,
#  'men': 465,
#  'back': 466,
#  'women': 467,
#  'industry': 468,
#  'assumed': 469,
#  'makeup': 470,
#  'hair': 471,
#  'person': 472,
#  'script': 473,
#  'never': 474,
#  'look': 475,
#  'around': 476,
#  'realised': 477,
#  'carve': 478,
#  'niche': 479,
#  'working': 480,
#  'greatest': 481,
#  'experiences': 482,
#  'ground': 483,
#  'trailblazed': 484,
#  'beginning': 485,
#  'followed': 486,
#  'anyone': 487,
#  'incredibly': 488,
#  'capable': 489,
#  'talented': 490,
#  'collaborated': 491,
#  'sequels': 492,
#  'ii': 493,
#  'resurrection': 494,
#  'curse': 495,
#  'michael': 496,
#  'myers': 497,
#  'later': 498,
#  'formed': 499,
#  'company': 500,
#  'friend': 501,
#  'lynda': 502,
#  'obst': 503,
#  'making': 504,
#  'string': 505,
#  'oscar': 506,
#  'nominee': 507,
#  'fisher': 508,
#  'king': 509,
#  'teen': 510,
#  'adventures': 511,
#  'babysitting': 512,
#  'included': 513,
#  'stephen': 514,
#  'adaptation': 515,
#  'dead': 516,
#  'zone': 517,
#  'clue': 518,
#  'based': 519,
#  'board': 520,
#  'game': 521,
#  'cluedo': 522,
#  'pursued': 523,
#  'although': 524,
#  'reunited': 525,
#  'la': 526,
#  'death': 527,
#  'two': 528,
#  'pulled': 529,
#  'rubble': 530,
#  'twin': 531,
#  'towers': 532,
#  'following': 533,
#  'september': 534,
#  'terror': 535,
#  'attacks': 536,
#  'coproducing': 537,
#  'due': 538,
#  'early': 539,
#  'next': 540,
#  'celebrities': 541,
#  'skates': 542,
#  'former': 543,
#  'england': 544,
#  'footballer': 545,
#  'paul': 546,
#  'gascoigne': 547,
#  'join': 548,
#  'eastenders': 549,
#  'scarlett': 550,
#  'johnson': 551,
#  'bbc': 552,
#  'strictly': 553,
#  'ice': 554,
#  'dancing': 555,
#  'oneoff': 556,
#  'special': 557,
#  'television': 558,
#  'presenter': 559,
#  'carol': 560,
#  'smillie': 561,
#  'jessica': 562,
#  'taylor': 563,
#  'libertyx': 564,
#  'celebrity': 565,
#  'paired': 566,
#  'professional': 567,
#  'skater': 568,
#  'impress': 569,
#  'panel': 570,
#  'judges': 571,
#  'win': 572,
#  'audience': 573,
#  'vote': 574,
#  'yet': 575,
#  'confirm': 576,
#  'stars': 577,
#  'battle': 578,
#  'become': 579,
#  'queen': 580,
#  'bruce': 581,
#  'forsyth': 582,
#  'tess': 583,
#  'daly': 584,
#  'host': 585,
#  'hot': 586,
#  'heels': 587,
#  'current': 588,
#  'saturday': 589,
#  'night': 590,
#  'practise': 591,
#  'stipulated': 592,
#  'dance': 593,
#  'perform': 594,
#  'rink': 595,
#  'partner': 596,
#  'decide': 597,
#  'wins': 598,
#  'contest': 599,
#  'forms': 600,
#  'part': 601,
#  'schedule': 602,
#  'skating': 603,
#  'duo': 604,
#  'jayne': 605,
#  'torvill': 606,
#  'christopher': 607,
#  'dean': 608,
#  'front': 609,
#  'similar': 610,
#  'itv': 611,
#  'titled': 612,
#  'thin': 613,
#  'contestants': 614,
#  'learn': 615,
#  'routine': 616,
#  'every': 617,
#  'end': 618,
#  'crowned': 619,
#  'winner': 620,
#  'mtv': 621,
#  'osbournes': 622,
#  'rock': 623,
#  'ozzy': 624,
#  'osbourne': 625,
#  'family': 626,
#  'episodes': 627,
#  'reality': 628,
#  'cameras': 629,
#  'house': 630,
#  'black': 631,
#  'sabbath': 632,
#  'singer': 633,
#  'reporters': 634,
#  'awards': 635,
#  'rome': 636,
#  'wife': 637,
#  'sharon': 638,
#  'appears': 639,
#  'popular': 640,
#  'agreed': 641,
#  'everybody': 642,
#  'shows': 643,
#  'something': 644,
#  'else': 645,
#  'enough': 646,
#  'involved': 647,
#  'episode': 648,
#  'filming': 649,
#  'currently': 650,
#  'appearing': 651,
#  'judge': 652,
#  'mentor': 653,
#  'talent': 654,
#  'xfactor': 655,
#  'alongside': 656,
#  'simon': 657,
#  'cowell': 658,
#  'louis': 659,
#  'walsh': 660,
#  'earlier': 661,
#  'topped': 662,
#  'poll': 663,
#  'important': 664,
#  'people': 665,
#  'guiding': 666,
#  'husband': 667,
#  'driving': 668,
#  'force': 669,
#  'ran': 670,
#  'earning': 671,
#  'reported': 672,
#  'renewed': 673,
#  'popularity': 674,
#  'seen': 675,
#  'merchandise': 676,
#  'mark': 677,
#  'heavy': 678,
#  'metal': 679,
#  'artist': 680,
#  'tshirts': 681,
#  'accessories': 682,
#  'action': 683,
#  'figures': 684,
#  'rocketed': 685,
#  'since': 686,
#  'screens': 687,
#  'peak': 688,
#  'regular': 689,
#  'eight': 690,
#  'million': 691,
#  'america': 692,
#  'guide': 693,
#  'magazine': 694,
#  'describing': 695,
#  'cross': 696,
#  'simpsons': 697,
#  'spinal': 698,
#  'tap': 699,
#  'loss': 700,
#  'explain': 701,
#  'suppose': 702,
#  'americans': 703,
#  'kick': 704,
#  'watching': 705,
#  'crazy': 706,
#  'brit': 707,
#  'complete': 708,
#  'fools': 709,
#  'row': 710,
#  'threatens': 711,
#  'hendrix': 712,
#  'museum': 713,
#  'plan': 714,
#  'proposals': 715,
#  'open': 716,
#  'dedicated': 717,
#  'jimi': 718,
#  'flailing': 719,
#  'home': 720,
#  'late': 721,
#  'father': 722,
#  'rundown': 723,
#  'seattle': 724,
#  'already': 725,
#  'moved': 726,
#  'wholesale': 727,
#  'local': 728,
#  'authorities': 729,
#  'demanding': 730,
#  'another': 731,
#  'site': 732,
#  'supporters': 733,
#  'hoped': 734,
#  'turn': 735,
#  'guitarist': 736,
#  'mayor': 737,
#  'go': 738,
#  'destroyed': 739,
#  'ray': 740,
#  'rae': 741,
#  'marshall': 742,
#  'james': 743,
#  'foundation': 744,
#  'building': 745,
#  'al': 746,
#  'lived': 747,
#  'land': 748,
#  'built': 749,
#  'developed': 750,
#  'housing': 751,
#  'city': 752,
#  'wants': 753,
#  'plot': 754,
#  'used': 755,
#  'development': 756,
#  'giving': 757,
#  'deadline': 758,
#  'february': 759,
#  'mr': 760,
#  'goldman': 761,
#  'authority': 762,
#  'promised': 763,
#  'could': 764,
#  'remain': 765,
#  'turned': 766,
#  'memorial': 767,
#  'community': 768,
#  'centre': 769,
#  'officials': 770,
#  'deal': 771,
#  'offered': 772,
#  'property': 773,
#  'franklin': 774,
#  'chief': 775,
#  'operations': 776,
#  'department': 777,
#  'perspective': 778,
#  'temporary': 779,
#  'situation': 780,
#  'threatened': 781,
#  'demolish': 782,
#  'simply': 783,
#  'asked': 784,
#  'move': 785,
#  'pay': 786,
#  'central': 787,
#  'district': 788,
#  'grew': 789,
#  'janie': 790,
#  'stepsister': 791,
#  'still': 792,
#  'hoping': 793,
#  'road': 794,
#  'named': 795,
#  'wanted': 796,
#  'see': 797,
#  'nice': 798,
#  'fight': 799,
#  'everything': 800,
#  'widely': 801,
#  'considered': 802,
#  'guitarists': 803,
#  'drug': 804,
#  'overdose': 805,
#  'age': 806,
#  'franz': 807,
#  'man': 808,
#  'seeks': 809,
#  'government': 810,
#  'help': 811,
#  'ferdinand': 812,
#  'frontman': 813,
#  'alex': 814,
#  'kapranos': 815,
#  'called': 816,
#  'musicians': 817,
#  'edinburgh': 818,
#  'lectures': 819,
#  'discussion': 820,
#  'cultural': 821,
#  'output': 822,
#  'thrive': 823,
#  'needs': 824,
#  'kind': 825,
#  'state': 826,
#  'input': 827,
#  'well': 828,
#  'warned': 829,
#  'linked': 830,
#  'mps': 831,
#  'event': 832,
#  'question': 833,
#  'politicians': 834,
#  'rather': 835,
#  'bed': 836,
#  'joined': 837,
#  'prestigious': 838,
#  'lecture': 839,
#  'discuss': 840,
#  'scotland': 841,
#  'century': 842,
#  'elements': 843,
#  'musical': 844,
#  'require': 845,
#  'sustenance': 846,
#  'selfsufficient': 847,
#  'socalled': 848,
#  'commercial': 849,
#  'benefit': 850,
#  'investment': 851,
#  'allied': 852,
#  'particular': 853,
#  'party': 854,
#  'know': 855,
#  'tea': 856,
#  'always': 857,
#  'idea': 858,
#  'glasgow': 859,
#  'fourpiece': 860,
#  'band': 861,
#  'prizes': 862,
#  'album': 863,
#  'selftitled': 864,
#  'mercury': 865,
#  'spawned': 866,
#  'singles': 867,
#  'reid': 868,
#  'hall': 869,
#  'listen': 870,
#  'wide': 871,
#  'range': 872,
#  'restricted': 873,
#  'stereotypes': 874,
#  'say': 875,
#  'nirvana': 876,
#  'korn': 877,
#  'troubled': 878,
#  'individual': 879,
#  'riddled': 880,
#  'angst': 881,
#  'chopin': 882,
#  'debussy': 883,
#  'kylie': 884,
#  'minogue': 885,
#  'scissor': 886,
#  'upbeat': 887,
#  'wagner': 888,
#  'smell': 889,
#  'napalm': 890,
#  'morning': 891,
#  'general': 892,
#  'hostility': 893,
#  'towards': 894,
#  'classical': 895,
#  'adding': 896,
#  'little': 897,
#  'break': 898,
#  'fm': 899,
#  'concluded': 900,
#  'define': 901,
#  'nation': 902,
#  'encourage': 903,
#  'creativity': 904,
#  'fellow': 905,
#  'speaker': 906,
#  'composer': 907,
#  'macmillan': 908,
#  'need': 909,
#  'rediscover': 910,
#  'ability': 911,
#  'speakers': 912,
#  'soviet': 913,
#  'leader': 914,
#  'mikhail': 915,
#  'gorbachev': 916,
#  'author': 917,
#  'professor': 918,
#  'hawking': 919,
#  'described': 920,
#  'wednesday': 921,
#  'daunting': 922,
#  'long': 923,
#  'upcoming': 924,
#  'brits': 925,
#  'care': 926,
#  'great': 927,
#  'actually': 928,
#  'exercise': 929,
#  'brain': 930,
#  'tonight': 931,
#  'upandcoming': 932,
#  'artists': 933,
#  'discovered': 934,
#  'scrapping': 935,
#  'entertainment': 936,
#  'licences': 937,
#  'live': 938,
#  'venues': 939,
#  'labels': 940,
#  'louder': 941,
#  'voice': 942,
#  'within': 943,
#  'dominated': 944,
#  'commercialised': 945,
#  'expecting': 946,
#  'ie': 947,
#  'taxpayer': 948,
#  'fork': 949,
#  'megastars': 950,
#  'put': 951,
#  'britain': 952,
#  'wealthiest': 953,
#  'raked': 954,
#  'albums': 955,
#  'concerts': 956,
#  'etc': 957,
#  'far': 958,
#  'demands': 959,
#  'funds': 960,
#  'fund': 961,
#  'football': 962,
#  'areas': 963,
#  'arts': 964,
#  'funded': 965,
#  'lottery': 966,
#  'grants': 967,
#  'receiving': 968,
#  'huge': 969,
#  'clearly': 970,
#  'beneficial': 971,
#  'diversity': 972,
#  'opportunities': 973,
#  'problem': 974,
#  'merits': 975,
#  'cash': 976,
#  'problems': 977,
#  'funding': 978,
#  'schools': 979,
#  'health': 980,
#  'services': 981,
#  'genuinely': 982,
#  'thinks': 983,
#  'multibillion': 984,
#  'pound': 985,
#  'education': 986,
#  'seriously': 987,
#  'lacking': 988,
#  'money': 989,
#  'scot': 990,
#  'living': 991,
#  'appreciate': 992,
#  'value': 993,
#  'scottish': 994,
#  'culture': 995,
#  'success': 996,
#  'travis': 997,
#  'snow': 998,
#  'patrol': 999,
#  ...}

# %%
window_size = 2
idx_pairs = []
# for each sentence
for sentence in tokenized_corpus:
    indices = [word2idx[word] for word in sentence]
    # for each word, threated as center word
    for center_word_pos in range(len(indices)):
        # for each window position
        for w in range(-window_size, window_size + 1):
            context_word_pos = center_word_pos + w
            # make soure not jump out sentence
            if context_word_pos < 0 or context_word_pos >= len(indices) or center_word_pos == context_word_pos:
                continue
            context_word_idx = indices[context_word_pos]
            idx_pairs.append((indices[center_word_pos], context_word_idx))

idx_pairs = np.array(idx_pairs) # it will be useful to have this as numpy array

# %%
idx_pairs[:10]
print(len(idx_pairs))
# Out:
# 23200

# %%
def get_input_layer(word_idx):
    x = torch.zeros(vocabulary_size).float()
    x[word_idx] = 1.0
    return x
  
  #Input layer is just the center word encoded in one-hot manner. It dimensions are [1, vocabulary_size]

# %%
embedding_dims = 5
W1 = Variable(torch.randn(embedding_dims, vocabulary_size).float(), requires_grad=True)
W2 = Variable(torch.randn(vocabulary_size, embedding_dims).float(), requires_grad=True)
num_epochs = 101
learning_rate = 0.001

for epo in range(num_epochs):
    loss_val = 0
    for data, target in idx_pairs:
        x = Variable(get_input_layer(data)).float()
        y_true = Variable(torch.from_numpy(np.array([target])).long())

        z1 = torch.matmul(W1, x)
        z2 = torch.matmul(W2, z1)
    
        log_softmax = F.log_softmax(z2, dim=0)

        loss = F.nll_loss(log_softmax.view(1,-1), y_true)
        loss_val += loss.data.item()
        loss.backward()
        W1.data -= learning_rate * W1.grad.data
        W2.data -= learning_rate * W2.grad.data

        W1.grad.data.zero_()
        W2.grad.data.zero_()
    if epo % 10 == 0:    
        print(f'Loss at epo {epo}: {loss_val/len(idx_pairs)}')
# Out:
# Loss at epo 0: 10.188550272630206
# Loss at epo 10: 9.1567762523684
# Loss at epo 20: 8.76288441806004
# Loss at epo 30: 8.521708915192505
# Loss at epo 40: 8.351950931528519
# Loss at epo 50: 8.22297350165145
# Loss at epo 60: 8.119606257409885
# Loss at epo 70: 8.033189343964231
# Loss at epo 80: 7.958316222269987
# Loss at epo 90: 7.89137461127906
# Loss at epo 100: 7.829868187508707

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
def lab1(word):
    index_of_word = -1
    for i in range(len(vocabulary)):
        if  (vocabulary[i] == word):
            index_of_word = i
    if (index_of_word < 0):
        print('This word does not exist on dataset')
    if (index_of_word >= 0):
        print('Index of the word', vocabulary[index_of_word],' is ',index_of_word)
        print('Task 1: Thensors of words')
        print(W2.data)
        cos_distance = []
        labels = []
        ta = np.array(W2.data)
        for j in range(len(W2)):
            result = np.dot(
                np.array(ta[j]),
                            np.array(ta[index_of_word]))
            /
            (((np.sum(ta[j]**2))**0.5) * ((np.sum(ta[index_of_word]**2))**0.5)
            )
            cos_distance.append([result, j])
        cos_distance_sorted = sorted(cos_distance, key=lambda x: x[0], reverse=True)
        for i in (range(10)):
            print(cos_distance_sorted[i], vocabulary[cos_distance_sorted[i][1]])
            labels.append(vocabulary[cos_distance_sorted[i][1]])
        array_for_dot_cloud = []
        array_for_dot_cloud_label = []
        for i in range(11):
            array_for_dot_cloud.append(np.array
                                       (ta[cos_distance_sorted[i][1]]))
            array_for_dot_cloud_label.append(vocabulary[cos_distance_sorted[i][1]])
        print(W2[cos_distance_sorted[i][1]], vocabulary[cos_distance_sorted[i][1]])
        array_for_dot_cloud = np.array(array_for_dot_cloud)
        print(array_for_dot_cloud)
        X_embedded = TSNE(n_components=2).fit_transform(array_for_dot_cloud)
        X_embedded.shape
        #print(X_embedded)
        x = []
        y = []
        new_values = X_embedded
        for value in new_values:
            x.append(value[0])
            y.append(value[1])
        plt.figure(figsize=(16, 16)) 
        for i in range(len(x)):
            plt.scatter(x[i],y[i])
            plt.annotate(array_for_dot_cloud_label[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
        plt.show()

# %%
lab1('america')
# Out:
# Index of the word america  is  692
# Task 1: Thensors of words
# tensor([[-1.8555,  0.6675,  0.4642,  0.2978,  0.6550],
#         [-0.3876,  0.6999,  1.7293,  0.2606,  0.5481],
#         [-0.6194,  0.8584,  1.2409,  0.1921,  0.7646],
#         ...,
#         [ 0.4763, -1.0605,  0.7784,  0.1631,  1.4132],
#         [ 0.6197, -0.7749,  0.6433, -0.3812,  1.3791],
#         [ 0.1676, -0.0662, -0.8555,  1.5114, -0.3350]])
# [3.1529343, 1699] def
# [2.5956392, 626] family
# [2.4945765, 1036] even
# [2.4687712, 325] story
# [2.438491, 1681] ontario
# [2.427651, 978] funding
# [2.4069576, 2322] springer
# [2.404486, 397] russell
# [2.3615909, 426] producer
# [2.3371394, 1491] dropout
# tensor([-1.0567,  1.1620,  0.0899, -1.0058, -0.2063], grad_fn=<SelectBackward>) favourite
# [[-0.6734899   2.1206415   0.36160168 -1.4922644  -0.5307572 ]
#  [-1.1829422   1.3251411   0.07385758 -1.0950907  -0.5483567 ]
#  [-0.8356972   1.3411436  -0.33403593 -0.8183784   0.5056261 ]
#  [-0.8259568   1.2207854   0.30497912 -1.4784669   0.3283118 ]
#  [-1.4737486   0.8820985  -0.6228271  -0.6385585   0.20328535]
#  [-0.177113    1.6897831  -1.6397434  -0.0560794   0.36037278]
#  [-1.1486638   1.2051474  -1.029739   -0.2625954  -0.47090206]
#  [-0.87803096  1.4903648  -1.0766368  -0.00544805 -0.3773626 ]
#  [-2.0132813   0.95611274  0.5456665  -0.12278315  1.3519499 ]
#  [-0.40210354  1.2141094  -1.6161743  -0.6683238  -0.24264239]
#  [-1.056655    1.1620345   0.08990442 -1.005812   -0.2062616 ]]

# %%
lab1('festival')
# Out:
# Index of the word festival  is  225
# Task 1: Thensors of words
# tensor([[-1.8555,  0.6675,  0.4642,  0.2978,  0.6550],
#         [-0.3876,  0.6999,  1.7293,  0.2606,  0.5481],
#         [-0.6194,  0.8584,  1.2409,  0.1921,  0.7646],
#         ...,
#         [ 0.4763, -1.0605,  0.7784,  0.1631,  1.4132],
#         [ 0.6197, -0.7749,  0.6433, -0.3812,  1.3791],
#         [ 0.1676, -0.0662, -0.8555,  1.5114, -0.3350]])
# [7.2550383, 419] best
# [6.65102, 341] actor
# [6.342246, 225] festival
# [5.868586, 276] including
# [5.7561903, 139] final
# [4.9042225, 1969] drake
# [4.6643863, 1830] tate
# [4.6068196, 415] year
# [4.60404, 18] one
# [4.532853, 1247] thursday
# tensor([-0.7495, -1.6292,  1.3320, -0.1952,  0.6456], grad_fn=<SelectBackward>) song
# [[-1.323599   -1.4053102   1.0568604  -1.5819236   2.6510844 ]
#  [-2.2562206  -0.9743181   0.30387124 -0.41384608  1.6040105 ]
#  [-1.5212599  -1.7713972  -0.11473943 -0.38808092  0.8522876 ]
#  [-0.87320185 -2.1020792  -1.1119161  -0.3179653   0.6636552 ]
#  [-1.5871636  -1.7233727   0.25850725 -1.076611   -0.11642447]
#  [-1.2394683  -1.1311263  -0.5609843  -1.0846009   0.6215217 ]
#  [-0.9863614  -1.2667406  -0.54364824 -0.5555328   0.7532717 ]
#  [ 0.6487577  -2.4234307  -1.3965418  -0.7418293   1.0005563 ]
#  [-1.4392066  -0.369795   -1.3622124  -0.5810034   1.6165941 ]
#  [-1.347831   -1.0574143  -0.37528485  0.48660937  0.88600975]
#  [-0.7494581  -1.6291589   1.3320104  -0.19521427  0.64559525]]
