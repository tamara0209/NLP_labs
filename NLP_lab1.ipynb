# %%
import string
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import re
import torch
from torch.autograd import Variable
import numpy as np
import torch.functional as F
import torch.nn.functional as F
import pandas as pd
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from string import punctuation
from nltk.stem.porter import *
from nltk.stem import WordNetLemmatizer
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

STOPWORDS = set(stopwords.words('english'))

# %%
dataset = pd.read_csv('/Users/ts/Downloads/bbc-text.csv')
dataset.head()
# Out:
#         category                                               text
# 0           tech  tv future in the hands of viewers with home th...
# 1       business  worldcom boss  left books alone  former worldc...
# 2          sport  tigers wary of farrell  gamble  leicester say ...
# 3          sport  yeading face newcastle in fa cup premiership s...
# 4  entertainment  ocean s twelve raids box office ocean s twelve...

# %%
def preprocess_text(text):
    '''Make text lowercase, remove text in square brackets, 
    remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub(r'\[.*?\]', '', text)
    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub(r'\w*\d\w*', '', text)
    # Remove a sentence if it is only one word long
    if len(text) > 2:
        return ' '.join(word for word in text.split() if word not in STOPWORDS)

dataset_clean = pd.DataFrame(dataset.text.apply(lambda x: preprocess_text(x)))

# %%
dataset_clean.head()
# Out:
#                                                 text
# 0  tv future hands viewers home theatre systems p...
# 1  worldcom boss left books alone former worldcom...
# 2  tigers wary farrell gamble leicester say rushe...
# 3  yeading face newcastle fa cup premiership side...
# 4  ocean twelve raids box office ocean twelve cri...

# %%
dataset = pd.read_csv('/Users/ts/Downloads/bbc-text.csv')
dataset = dataset[dataset.category == 'entertainment']
dataset.index = np.arange(len(dataset))
dataset = dataset[:30]
print(dataset.head())
print(len(dataset))
# Out:
#         category                                               text
# 0  entertainment  ocean s twelve raids box office ocean s twelve...
# 1  entertainment  last star wars  not for children  the sixth an...
# 2  entertainment  berlin cheers for anti-nazi film a german movi...
# 3  entertainment  career honour for actor dicaprio actor leonard...
# 4  entertainment  halloween writer debra hill dies screenwriter ...
# 30

# %%
corpus = dataset['text']
print(corpus)
# Out:
# 0     ocean s twelve raids box office ocean s twelve...
# 1     last star wars  not for children  the sixth an...
# 2     berlin cheers for anti-nazi film a german movi...
# 3     career honour for actor dicaprio actor leonard...
# 4     halloween writer debra hill dies screenwriter ...
# 5     celebrities get their skates on former england...
# 6     show over for mtv s the osbournes rock star oz...
# 7     row threatens hendrix museum plan proposals to...
# 8     franz man seeks government help franz ferdinan...
# 9     top of the pops leaves bbc one the bbc s flags...
# 10    controversial film tops festival a controversi...
# 11    cult band kasabian surge forward indie dance b...
# 12    rapper kanye west s shrewd soul us hip-hop sta...
# 13    housewives lift channel 4 ratings the debut of...
# 14    lit idol begins search for author the second p...
# 15    rapper jay-z becomes label boss rap star jay-z...
# 16    berlin hails european cinema organisers say th...
# 17    byrds producer melcher dies at 62 record produ...
# 18    animation charms japan box office oscar-winnin...
# 19    slater to star in broadway play actor christia...
# 20    film production  falls  40% in uk the number o...
# 21    hillbillies singer scoggins dies country and w...
# 22    bennett play takes theatre prizes the history ...
# 23    the comic book genius of stan lee stan lee  th...
# 24    goodrem wins top female mtv prize pop singer d...
# 25    musical treatment for capra film the classic f...
# 26    springer criticises opera musical talk show ho...
# 27    stars gear up for bafta ceremony film stars fr...
# 28    carry on star patsy rowlands dies actress pats...
# 29    grammys honour soul star charles the memory of...
# Name: text, dtype: object

# %%
tokenized_corpus = []
stemmer = PorterStemmer()
for i in range(len(corpus)):
    sentence = preprocess(corpus[i])
    tokenized_corpus.append(word_tokenize((sentence)))
print(tokenized_corpus)
# Out:
# [['ocean', 'twelve', 'raids', 'box', 'office', 'ocean', 'twelve', 'crime', 'caper', 'sequel', 'starring', 'george', 'clooney', 'brad', 'pitt', 'julia', 'roberts', 'gone', 'straight', 'number', 'one', 'us', 'box', 'office', 'chart', 'took', '8m', '21m', 'weekend', 'ticket', 'sales', 'according', 'studio', 'estimates', 'sequel', 'follows', 'master', 'criminals', 'try', 'pull', 'three', 'major', 'heists', 'across', 'europe', 'knocked', 'last', 'week', 'number', 'one', 'national', 'treasure', 'third', 'place', 'wesley', 'snipes', 'blade', 'trinity', 'second', 'taking', '1m', '4m', 'rounding', 'top', 'five', 'animated', 'fable', 'polar', 'express', 'starring', 'tom', 'hanks', 'festive', 'comedy', 'christmas', 'kranks', 'ocean', 'twelve', 'box', 'office', 'triumph', 'marks', 'fourth', 'biggest', 'opening', 'december', 'release', 'us', 'three', 'films', 'lord', 'rings', 'trilogy', 'sequel', 'narrowly', 'beat', 'predecessor', 'ocean', 'eleven', 'took', '1m', '8m', 'opening', 'weekend', '184m', '8m', 'total', 'remake', '1960s', 'film', 'starring', 'frank', 'sinatra', 'rat', 'pack', 'ocean', 'eleven', 'directed', 'oscar', 'winning', 'director', 'steven', 'soderbergh', 'soderbergh', 'returns', 'direct', 'hit', 'sequel', 'reunites', 'clooney', 'pitt', 'roberts', 'matt', 'damon', 'andy', 'garcia', 'elliott', 'gould', 'catherine', 'zeta', 'jones', 'joins', 'star', 'cast', 'fun', 'good', 'holiday', 'movie', 'said', 'dan', 'fellman', 'president', 'distribution', 'warner', 'bros', 'however', 'us', 'critics', 'less', 'complimentary', '110m', '2m', 'project', 'los', 'angeles', 'times', 'labelling', 'dispiriting', 'vanity', 'project', 'milder', 'review', 'new', 'york', 'times', 'dubbed', 'sequel', 'unabashedly', 'trivial'], ['last', 'star', 'wars', 'children', 'sixth', 'final', 'star', 'wars', 'movie', 'may', 'suitable', 'young', 'children', 'film', 'maker', 'george', 'lucas', 'said', 'told', 'us', 'tv', 'show', 'minutes', 'revenge', 'sith', 'would', 'darkest', 'violent', 'series', 'think', 'would', 'take', 'five', 'six', 'year', 'old', 'told', 'cbs', 'programme', 'aired', 'sunday', 'lucas', 'predicted', 'film', 'would', 'get', 'us', 'rating', 'advising', 'parents', 'scenes', 'may', 'unsuitable', '13s', 'opens', 'uk', 'us', 'may', 'said', 'expected', 'film', 'would', 'classified', 'pg', 'roughly', 'equivalent', 'british', '12a', 'rating', 'five', 'previous', 'star', 'wars', 'films', 'carried', 'less', 'restrictive', 'pg', 'parental', 'guidance', 'ratings', 'us', 'uk', 'passed', 'u', 'suitable', 'exception', 'attack', 'clones', 'got', 'pg', 'rating', 'revenge', 'sith', 'third', 'prequel', 'original', 'star', 'wars', 'film', 'chronicles', 'transformation', 'heroic', 'anakin', 'skywalker', 'evil', 'darth', 'vader', 'travels', 'hell', 'like', 'planet', 'composed', 'erupting', 'volcanoes', 'molten', 'lava', 'going', 'watch', 'make', 'pact', 'devil', 'lucas', 'said', 'film', 'much', 'dark', 'emotional', 'much', 'tragedy'], ['berlin', 'cheers', 'anti', 'nazi', 'film', 'german', 'movie', 'anti', 'nazi', 'resistance', 'heroine', 'drawn', 'loud', 'applause', 'berlin', 'film', 'festival', 'sophie', 'scholl', 'final', 'days', 'portrays', 'final', 'days', 'member', 'white', 'rose', 'movement', 'scholl', 'arrested', 'beheaded', 'brother', 'hans', 'distributing', 'leaflets', 'condemning', 'abhorrent', 'tyranny', 'adolf', 'hitler', 'director', 'marc', 'rothemund', 'said', 'feeling', 'responsibility', 'keep', 'legacy', 'scholls', 'going', 'must', 'somehow', 'keep', 'ideas', 'alive', 'added', 'film', 'drew', 'transcripts', 'gestapo', 'interrogations', 'scholl', 'trial', 'preserved', 'archive', 'communist', 'east', 'germany', 'secret', 'police', 'discovery', 'inspiration', 'behind', 'film', 'rothemund', 'worked', 'closely', 'surviving', 'relatives', 'including', 'one', 'scholl', 'sisters', 'ensure', 'historical', 'accuracy', 'film', 'scholl', 'members', 'white', 'rose', 'resistance', 'group', 'first', 'started', 'distributing', 'anti', 'nazi', 'leaflets', 'summer', ...

# %%
import nltk
nltk.download('wordnet')
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to /Users/ts/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/ts/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
vocabulary = []
for sentence in tokenized_corpus:
    for token in sentence:
        if token not in vocabulary:
            vocabulary.append(token)

word2idx = {w: idx for (idx, w) in enumerate(vocabulary)}
idx2word = {idx: w for (idx, w) in enumerate(vocabulary)}

vocabulary_size = len(vocabulary)

# %%
word2idx
# Out:
# {'ocean': 0,
#  'twelve': 1,
#  'raids': 2,
#  'box': 3,
#  'office': 4,
#  'crime': 5,
#  'caper': 6,
#  'sequel': 7,
#  'starring': 8,
#  'george': 9,
#  'clooney': 10,
#  'brad': 11,
#  'pitt': 12,
#  'julia': 13,
#  'roberts': 14,
#  'gone': 15,
#  'straight': 16,
#  'number': 17,
#  'one': 18,
#  'us': 19,
#  'chart': 20,
#  'took': 21,
#  '8m': 22,
#  '21m': 23,
#  'weekend': 24,
#  'ticket': 25,
#  'sales': 26,
#  'according': 27,
#  'studio': 28,
#  'estimates': 29,
#  'follows': 30,
#  'master': 31,
#  'criminals': 32,
#  'try': 33,
#  'pull': 34,
#  'three': 35,
#  'major': 36,
#  'heists': 37,
#  'across': 38,
#  'europe': 39,
#  'knocked': 40,
#  'last': 41,
#  'week': 42,
#  'national': 43,
#  'treasure': 44,
#  'third': 45,
#  'place': 46,
#  'wesley': 47,
#  'snipes': 48,
#  'blade': 49,
#  'trinity': 50,
#  'second': 51,
#  'taking': 52,
#  '1m': 53,
#  '4m': 54,
#  'rounding': 55,
#  'top': 56,
#  'five': 57,
#  'animated': 58,
#  'fable': 59,
#  'polar': 60,
#  'express': 61,
#  'tom': 62,
#  'hanks': 63,
#  'festive': 64,
#  'comedy': 65,
#  'christmas': 66,
#  'kranks': 67,
#  'triumph': 68,
#  'marks': 69,
#  'fourth': 70,
#  'biggest': 71,
#  'opening': 72,
#  'december': 73,
#  'release': 74,
#  'films': 75,
#  'lord': 76,
#  'rings': 77,
#  'trilogy': 78,
#  'narrowly': 79,
#  'beat': 80,
#  'predecessor': 81,
#  'eleven': 82,
#  '184m': 83,
#  'total': 84,
#  'remake': 85,
#  '1960s': 86,
#  'film': 87,
#  'frank': 88,
#  'sinatra': 89,
#  'rat': 90,
#  'pack': 91,
#  'directed': 92,
#  'oscar': 93,
#  'winning': 94,
#  'director': 95,
#  'steven': 96,
#  'soderbergh': 97,
#  'returns': 98,
#  'direct': 99,
#  'hit': 100,
#  'reunites': 101,
#  'matt': 102,
#  'damon': 103,
#  'andy': 104,
#  'garcia': 105,
#  'elliott': 106,
#  'gould': 107,
#  'catherine': 108,
#  'zeta': 109,
#  'jones': 110,
#  'joins': 111,
#  'star': 112,
#  'cast': 113,
#  'fun': 114,
#  'good': 115,
#  'holiday': 116,
#  'movie': 117,
#  'said': 118,
#  'dan': 119,
#  'fellman': 120,
#  'president': 121,
#  'distribution': 122,
#  'warner': 123,
#  'bros': 124,
#  'however': 125,
#  'critics': 126,
#  'less': 127,
#  'complimentary': 128,
#  '110m': 129,
#  '2m': 130,
#  'project': 131,
#  'los': 132,
#  'angeles': 133,
#  'times': 134,
#  'labelling': 135,
#  'dispiriting': 136,
#  'vanity': 137,
#  'milder': 138,
#  'review': 139,
#  'new': 140,
#  'york': 141,
#  'dubbed': 142,
#  'unabashedly': 143,
#  'trivial': 144,
#  'wars': 145,
#  'children': 146,
#  'sixth': 147,
#  'final': 148,
#  'may': 149,
#  'suitable': 150,
#  'young': 151,
#  'maker': 152,
#  'lucas': 153,
#  'told': 154,
#  'tv': 155,
#  'show': 156,
#  'minutes': 157,
#  'revenge': 158,
#  'sith': 159,
#  'would': 160,
#  'darkest': 161,
#  'violent': 162,
#  'series': 163,
#  'think': 164,
#  'take': 165,
#  'six': 166,
#  'year': 167,
#  'old': 168,
#  'cbs': 169,
#  'programme': 170,
#  'aired': 171,
#  'sunday': 172,
#  'predicted': 173,
#  'get': 174,
#  'rating': 175,
#  'advising': 176,
#  'parents': 177,
#  'scenes': 178,
#  'unsuitable': 179,
#  '13s': 180,
#  'opens': 181,
#  'uk': 182,
#  'expected': 183,
#  'classified': 184,
#  'pg': 185,
#  'roughly': 186,
#  'equivalent': 187,
#  'british': 188,
#  '12a': 189,
#  'previous': 190,
#  'carried': 191,
#  'restrictive': 192,
#  'parental': 193,
#  'guidance': 194,
#  'ratings': 195,
#  'passed': 196,
#  'u': 197,
#  'exception': 198,
#  'attack': 199,
#  'clones': 200,
#  'got': 201,
#  'prequel': 202,
#  'original': 203,
#  'chronicles': 204,
#  'transformation': 205,
#  'heroic': 206,
#  'anakin': 207,
#  'skywalker': 208,
#  'evil': 209,
#  'darth': 210,
#  'vader': 211,
#  'travels': 212,
#  'hell': 213,
#  'like': 214,
#  'planet': 215,
#  'composed': 216,
#  'erupting': 217,
#  'volcanoes': 218,
#  'molten': 219,
#  'lava': 220,
#  'going': 221,
#  'watch': 222,
#  'make': 223,
#  'pact': 224,
#  'devil': 225,
#  'much': 226,
#  'dark': 227,
#  'emotional': 228,
#  'tragedy': 229,
#  'berlin': 230,
#  'cheers': 231,
#  'anti': 232,
#  'nazi': 233,
#  'german': 234,
#  'resistance': 235,
#  'heroine': 236,
#  'drawn': 237,
#  'loud': 238,
#  'applause': 239,
#  'festival': 240,
#  'sophie': 241,
#  'scholl': 242,
#  'days': 243,
#  'portrays': 244,
#  'member': 245,
#  'white': 246,
#  'rose': 247,
#  'movement': 248,
#  'arrested': 249,
#  'beheaded': 250,
#  'brother': 251,
#  'hans': 252,
#  'distributing': 253,
#  'leaflets': 254,
#  'condemning': 255,
#  'abhorrent': 256,
#  'tyranny': 257,
#  'adolf': 258,
#  'hitler': 259,
#  'marc': 260,
#  'rothemund': 261,
#  'feeling': 262,
#  'responsibility': 263,
#  'keep': 264,
#  'legacy': 265,
#  'scholls': 266,
#  'must': 267,
#  'somehow': 268,
#  'ideas': 269,
#  'alive': 270,
#  'added': 271,
#  'drew': 272,
#  'transcripts': 273,
#  'gestapo': 274,
#  'interrogations': 275,
#  'trial': 276,
#  'preserved': 277,
#  'archive': 278,
#  'communist': 279,
#  'east': 280,
#  'germany': 281,
#  'secret': 282,
#  'police': 283,
#  'discovery': 284,
#  'inspiration': 285,
#  'behind': 286,
#  'worked': 287,
#  'closely': 288,
#  'surviving': 289,
#  'relatives': 290,
#  'including': 291,
#  'sisters': 292,
#  'ensure': 293,
#  'historical': 294,
#  'accuracy': 295,
#  'members': 296,
#  'group': 297,
#  'first': 298,
#  'started': 299,
#  'summer': 300,
#  'dropped': 301,
#  'munich': 302,
#  'university': 303,
#  'calling': 304,
#  'day': 305,
#  'reckoning': 306,
#  'regime': 307,
#  'focuses': 308,
#  'arrest': 309,
#  'intense': 310,
#  'saw': 311,
#  'initially': 312,
#  'deny': 313,
#  'charges': 314,
#  'ended': 315,
#  'defiant': 316,
#  'appearance': 317,
#  'vying': 318,
#  'prize': 319,
#  'south': 320,
#  'african': 321,
#  'version': 322,
#  'bizet': 323,
#  'tragic': 324,
#  'opera': 325,
#  'carmen': 326,
#  'shot': 327,
#  'cape': 328,
#  'town': 329,
#  'xhosa': 330,
#  'language': 331,
#  'also': 332,
#  'premiered': 333,
#  'entitled': 334,
#  'ekhayelitsha': 335,
#  'khayelitsha': 336,
#  'township': 337,
#  'story': 338,
#  'set': 339,
#  'performed': 340,
#  'strong': 341,
#  'music': 342,
#  'theatre': 343,
#  'troupe': 344,
#  'debut': 345,
#  'performance': 346,
#  'feature': 347,
#  'years': 348,
#  'nominated': 349,
#  'golden': 350,
#  'bear': 351,
#  'award': 352,
#  'career': 353,
#  'honour': 354,
#  'actor': 355,
#  'dicaprio': 356,
#  'leonardo': 357,
#  'exceptional': 358,
#  'honoured': 359,
#  'santa': 360,
#  'barbara': 361,
#  'international': 362,
#  'presented': 363,
#  'martin': 364,
#  'scorsese': 365,
#  'aviator': 366,
#  'lifetime': 367,
#  'achievement': 368,
#  'completely': 369,
#  'utterly': 370,
#  'surreal': 371,
#  'given': 372,
#  'almost': 373,
#  'done': 374,
#  'quite': 375,
#  'retrospective': 376,
#  'movies': 377,
#  'shown': 378,
#  'really': 379,
#  'exciting': 380,
#  'love': 381,
#  'want': 382,
#  'rest': 383,
#  'life': 384,
#  'began': 385,
#  'horror': 386,
#  'critters': 387,
#  'moving': 388,
#  'onto': 389,
#  'roles': 390,
#  'basketball': 391,
#  'diaries': 392,
#  'romeo': 393,
#  'juliet': 394,
#  'titanic': 395,
#  'gangs': 396,
#  'created': 397,
#  'commemorate': 398,
#  'california': 399,
#  '20th': 400,
#  'anniversary': 401,
#  'coincided': 402,
#  'portrayal': 403,
#  'millionaire': 404,
#  'howard': 405,
#  'hughes': 406,
#  'veteran': 407,
#  'actress': 408,
#  'jane': 409,
#  'russell': 410,
#  'starred': 411,
#  'outlaw': 412,
#  'impressed': 413,
#  'quest': 414,
#  'authenticity': 415,
#  'previously': 416,
#  'discussed': 417,
#  'role': 418,
#  'happy': 419,
#  'came': 420,
#  'cared': 421,
#  'come': 422,
#  'find': 423,
#  'taken': 424,
#  'pole': 425,
#  'position': 426,
#  'oscars': 427,
#  'race': 428,
#  'nominations': 429,
#  'best': 430,
#  'halloween': 431,
#  'writer': 432,
#  'debra': 433,
#  'hill': 434,
#  'dies': 435,
#  'screenwriter': 436,
#  'producer': 437,
#  'known': 438,
#  'work': 439,
#  '70s': 440,
#  'classic': 441,
#  'died': 442,
#  'aged': 443,
#  'suffering': 444,
#  'cancer': 445,
#  'co': 446,
#  'wrote': 447,
#  'jamie': 448,
#  'lee': 449,
#  'curtis': 450,
#  'babysitter': 451,
#  'terrorised': 452,
#  'psychopath': 453,
#  'john': 454,
#  'carpenter': 455,
#  'made': 456,
#  '60m': 457,
#  '3m': 458,
#  'worldwide': 459,
#  'record': 460,
#  'independent': 461,
#  'time': 462,
#  'escape': 463,
#  'fog': 464,
#  'born': 465,
#  'jersey': 466,
#  'production': 467,
#  'assistant': 468,
#  'way': 469,
#  'ranks': 470,
#  'becoming': 471,
#  'unit': 472,
#  'collaborating': 473,
#  'regarded': 474,
#  'many': 475,
#  'pioneering': 476,
#  'woman': 477,
#  'jobs': 478,
#  'commonly': 479,
#  'men': 480,
#  'back': 481,
#  'women': 482,
#  'industry': 483,
#  'assumed': 484,
#  'hair': 485,
#  'person': 486,
#  'script': 487,
#  'never': 488,
#  'look': 489,
#  'around': 490,
#  'realised': 491,
#  'carve': 492,
#  'niche': 493,
#  'working': 494,
#  'greatest': 495,
#  'experiences': 496,
#  'ground': 497,
#  'trailblazed': 498,
#  'beginning': 499,
#  'followed': 500,
#  'anyone': 501,
#  'incredibly': 502,
#  'capable': 503,
#  'talented': 504,
#  'collaborated': 505,
#  'sequels': 506,
#  'ii': 507,
#  'resurrection': 508,
#  'curse': 509,
#  'michael': 510,
#  'myers': 511,
#  'later': 512,
#  'formed': 513,
#  'company': 514,
#  'friend': 515,
#  'lynda': 516,
#  'obst': 517,
#  'making': 518,
#  'string': 519,
#  'nominee': 520,
#  'fisher': 521,
#  'king': 522,
#  'teen': 523,
#  'adventures': 524,
#  'babysitting': 525,
#  'included': 526,
#  'stephen': 527,
#  'adaptation': 528,
#  'dead': 529,
#  'zone': 530,
#  'clue': 531,
#  'based': 532,
#  'board': 533,
#  'game': 534,
#  'cluedo': 535,
#  '90s': 536,
#  'pursued': 537,
#  'although': 538,
#  'reunited': 539,
#  'la': 540,
#  'death': 541,
#  'two': 542,
#  'pulled': 543,
#  'rubble': 544,
#  'twin': 545,
#  'towers': 546,
#  'following': 547,
#  'september': 548,
#  'terror': 549,
#  'attacks': 550,
#  'producing': 551,
#  'due': 552,
#  'early': 553,
#  'next': 554,
#  'celebrities': 555,
#  'skates': 556,
#  'former': 557,
#  'england': 558,
#  'footballer': 559,
#  'paul': 560,
#  'gascoigne': 561,
#  'join': 562,
#  'eastenders': 563,
#  'scarlett': 564,
#  'johnson': 565,
#  'bbc': 566,
#  'strictly': 567,
#  'ice': 568,
#  'dancing': 569,
#  'special': 570,
#  'television': 571,
#  'presenter': 572,
#  'carol': 573,
#  'smillie': 574,
#  'jessica': 575,
#  'taylor': 576,
#  'liberty': 577,
#  'x': 578,
#  'celebrity': 579,
#  'paired': 580,
#  'professional': 581,
#  'skater': 582,
#  'impress': 583,
#  'panel': 584,
#  'judges': 585,
#  'win': 586,
#  'audience': 587,
#  'vote': 588,
#  'yet': 589,
#  'confirm': 590,
#  'stars': 591,
#  'battle': 592,
#  'become': 593,
#  'queen': 594,
#  'bruce': 595,
#  'forsyth': 596,
#  'tess': 597,
#  'daly': 598,
#  'host': 599,
#  'hot': 600,
#  'heels': 601,
#  'current': 602,
#  'saturday': 603,
#  'night': 604,
#  'practise': 605,
#  'stipulated': 606,
#  'dance': 607,
#  'perform': 608,
#  'rink': 609,
#  'partner': 610,
#  'decide': 611,
#  'wins': 612,
#  'contest': 613,
#  'forms': 614,
#  'part': 615,
#  'schedule': 616,
#  'skating': 617,
#  'duo': 618,
#  'jayne': 619,
#  'torvill': 620,
#  'christopher': 621,
#  'dean': 622,
#  'front': 623,
#  'similar': 624,
#  'itv': 625,
#  'titled': 626,
#  'thin': 627,
#  'contestants': 628,
#  'learn': 629,
#  'routine': 630,
#  'every': 631,
#  'end': 632,
#  'crowned': 633,
#  'winner': 634,
#  'mtv': 635,
#  'osbournes': 636,
#  'rock': 637,
#  'ozzy': 638,
#  'osbourne': 639,
#  'family': 640,
#  'episodes': 641,
#  'reality': 642,
#  'cameras': 643,
#  'house': 644,
#  'black': 645,
#  'sabbath': 646,
#  'singer': 647,
#  'reporters': 648,
#  'awards': 649,
#  'rome': 650,
#  'wife': 651,
#  'sharon': 652,
#  'appears': 653,
#  'popular': 654,
#  'agreed': 655,
#  'everybody': 656,
#  'shows': 657,
#  'something': 658,
#  'else': 659,
#  'enough': 660,
#  'involved': 661,
#  'minute': 662,
#  'episode': 663,
#  'filming': 664,
#  'currently': 665,
#  'appearing': 666,
#  'judge': 667,
#  'mentor': 668,
#  'itv1': 669,
#  'talent': 670,
#  'factor': 671,
#  'alongside': 672,
#  'simon': 673,
#  'cowell': 674,
#  'louis': 675,
#  'walsh': 676,
#  'earlier': 677,
#  'topped': 678,
#  'poll': 679,
#  'important': 680,
#  'people': 681,
#  'guiding': 682,
#  'husband': 683,
#  'driving': 684,
#  'force': 685,
#  'ran': 686,
#  'earning': 687,
#  'reported': 688,
#  '85m': 689,
#  '46m': 690,
#  'renewed': 691,
#  'popularity': 692,
#  'seen': 693,
#  'merchandise': 694,
#  '50m': 695,
#  'mark': 696,
#  'heavy': 697,
#  'metal': 698,
#  'artist': 699,
#  'shirts': 700,
#  'accessories': 701,
#  'action': 702,
#  'figures': 703,
#  'rocketed': 704,
#  'since': 705,
#  'screens': 706,
#  'peak': 707,
#  'regular': 708,
#  'eight': 709,
#  'million': 710,
#  'america': 711,
#  'guide': 712,
#  'magazine': 713,
#  'describing': 714,
#  'cross': 715,
#  'simpsons': 716,
#  'spinal': 717,
#  'tap': 718,
#  'loss': 719,
#  'explain': 720,
#  'suppose': 721,
#  'americans': 722,
#  'kick': 723,
#  'watching': 724,
#  'crazy': 725,
#  'brit': 726,
#  'complete': 727,
#  'fools': 728,
#  'row': 729,
#  'threatens': 730,
#  'hendrix': 731,
#  'museum': 732,
#  'plan': 733,
#  'proposals': 734,
#  'open': 735,
#  'dedicated': 736,
#  'jimi': 737,
#  'flailing': 738,
#  'home': 739,
#  'late': 740,
#  'father': 741,
#  'run': 742,
#  'seattle': 743,
#  'already': 744,
#  'moved': 745,
#  'wholesale': 746,
#  'local': 747,
#  'authorities': 748,
#  'demanding': 749,
#  'another': 750,
#  'site': 751,
#  'supporters': 752,
#  'hoped': 753,
#  'turn': 754,
#  'guitarist': 755,
#  'mayor': 756,
#  'go': 757,
#  'destroyed': 758,
#  'ray': 759,
#  'rae': 760,
#  'marshall': 761,
#  'james': 762,
#  'foundation': 763,
#  'building': 764,
#  'al': 765,
#  'lived': 766,
#  'land': 767,
#  'built': 768,
#  'developed': 769,
#  'housing': 770,
#  'city': 771,
#  'wants': 772,
#  'plot': 773,
#  'used': 774,
#  'development': 775,
#  'giving': 776,
#  'deadline': 777,
#  'february': 778,
#  'mr': 779,
#  'goldman': 780,
#  'authority': 781,
#  'promised': 782,
#  'could': 783,
#  'remain': 784,
#  'turned': 785,
#  'memorial': 786,
#  'community': 787,
#  'centre': 788,
#  'officials': 789,
#  'deal': 790,
#  'offered': 791,
#  'property': 792,
#  'franklin': 793,
#  'chief': 794,
#  'operations': 795,
#  'department': 796,
#  'perspective': 797,
#  'temporary': 798,
#  'situation': 799,
#  'threatened': 800,
#  'demolish': 801,
#  'simply': 802,
#  'asked': 803,
#  'move': 804,
#  'pay': 805,
#  'central': 806,
#  'district': 807,
#  'grew': 808,
#  'janie': 809,
#  'stepsister': 810,
#  'still': 811,
#  'hoping': 812,
#  'road': 813,
#  'named': 814,
#  'wanted': 815,
#  'see': 816,
#  'nice': 817,
#  'fight': 818,
#  'everything': 819,
#  'widely': 820,
#  'considered': 821,
#  'guitarists': 822,
#  'drug': 823,
#  'overdose': 824,
#  'age': 825,
#  'franz': 826,
#  'man': 827,
#  'seeks': 828,
#  'government': 829,
#  'help': 830,
#  'ferdinand': 831,
#  'frontman': 832,
#  'alex': 833,
#  'kapranos': 834,
#  'called': 835,
#  'musicians': 836,
#  'edinburgh': 837,
#  'lectures': 838,
#  'discussion': 839,
#  'cultural': 840,
#  'output': 841,
#  'thrive': 842,
#  'needs': 843,
#  'kind': 844,
#  'state': 845,
#  'input': 846,
#  'well': 847,
#  'warned': 848,
#  'linked': 849,
#  'mps': 850,
#  'event': 851,
#  'question': 852,
#  'politicians': 853,
#  'rather': 854,
#  'bed': 855,
#  'joined': 856,
#  'prestigious': 857,
#  'lecture': 858,
#  'discuss': 859,
#  'scotland': 860,
#  '21st': 861,
#  'century': 862,
#  'elements': 863,
#  'musical': 864,
#  'require': 865,
#  'sustenance': 866,
#  'self': 867,
#  'sufficient': 868,
#  'commercial': 869,
#  'benefit': 870,
#  'investment': 871,
#  'allied': 872,
#  'particular': 873,
#  'party': 874,
#  'know': 875,
#  'tea': 876,
#  'always': 877,
#  'idea': 878,
#  'glasgow': 879,
#  'four': 880,
#  'piece': 881,
#  'band': 882,
#  'prizes': 883,
#  'album': 884,
#  'mercury': 885,
#  'spawned': 886,
#  'singles': 887,
#  'reid': 888,
#  'hall': 889,
#  'listen': 890,
#  'wide': 891,
#  'range': 892,
#  'restricted': 893,
#  'stereotypes': 894,
#  'say': 895,
#  'nirvana': 896,
#  'korn': 897,
#  'troubled': 898,
#  'individual': 899,
#  'riddled': 900,
#  'angst': 901,
#  'chopin': 902,
#  'debussy': 903,
#  'kylie': 904,
#  'minogue': 905,
#  'scissor': 906,
#  'upbeat': 907,
#  'wagner': 908,
#  'smell': 909,
#  'napalm': 910,
#  'morning': 911,
#  'general': 912,
#  'hostility': 913,
#  'towards': 914,
#  'classical': 915,
#  'adding': 916,
#  'little': 917,
#  'break': 918,
#  'fm': 919,
#  'concluded': 920,
#  'define': 921,
#  'nation': 922,
#  'encourage': 923,
#  'creativity': 924,
#  'fellow': 925,
#  'speaker': 926,
#  'composer': 927,
#  'macmillan': 928,
#  'need': 929,
#  'rediscover': 930,
#  'ability': 931,
#  'speakers': 932,
#  'soviet': 933,
#  'leader': 934,
#  'mikhail': 935,
#  'gorbachev': 936,
#  'author': 937,
#  'professor': 938,
#  'hawking': 939,
#  'described': 940,
#  'wednesday': 941,
#  'daunting': 942,
#  'long': 943,
#  'upcoming': 944,
#  'brits': 945,
#  'care': 946,
#  'great': 947,
#  'actually': 948,
#  'exercise': 949,
#  'brain': 950,
#  'tonight': 951,
#  'coming': 952,
#  'artists': 953,
#  'discovered': 954,
#  'scrapping': 955,
#  'entertainment': 956,
#  'licences': 957,
#  'live': 958,
#  'venues': 959,
#  'labels': 960,
#  'louder': 961,
#  'voice': 962,
#  'within': 963,
#  'dominated': 964,
#  'commercialised': 965,
#  'expecting': 966,
#  'e': 967,
#  'taxpayer': 968,
#  'fork': 969,
#  'megastars': 970,
#  'put': 971,
#  'britain': 972,
#  'wealthiest': 973,
#  'raked': 974,
#  'albums': 975,
#  'concerts': 976,
#  'etc': 977,
#  'far': 978,
#  'demands': 979,
#  'funds': 980,
#  'fund': 981,
#  'football': 982,
#  'areas': 983,
#  'arts': 984,
#  'funded': 985,
#  'lottery': 986,
#  'grants': 987,
#  'receiving': 988,
#  'huge': 989,
#  'clearly': 990,
#  'beneficial': 991,
#  'diversity': 992,
#  'opportunities': 993,
#  'problem': 994,
#  'merits': 995,
#  'cash': 996,
#  'problems': 997,
#  'funding': 998,
#  'schools': 999,
#  ...}

# %%
window_size = 2
idx_pairs = []
# for each sentence
for sentence in tokenized_corpus:
    indices = [word2idx[word] for word in sentence]
    # for each word, threated as center word
    for center_word_pos in range(len(indices)):
        # for each window position
        for w in range(-window_size, window_size + 1):
            context_word_pos = center_word_pos + w
            # make soure not jump out sentence
            if context_word_pos < 0 or context_word_pos >= len(indices) or center_word_pos == context_word_pos:
                continue
            context_word_idx = indices[context_word_pos]
            idx_pairs.append((indices[center_word_pos], context_word_idx))

idx_pairs = np.array(idx_pairs) # it will be useful to have this as numpy array

# %%
idx_pairs[:10]
print(len(idx_pairs))
# Out:
# 23804

# %%
def get_input_layer(word_idx):
    x = torch.zeros(vocabulary_size).float()
    x[word_idx] = 1.0
    return x
  
  #Input layer is just the center word encoded in one-hot manner. It dimensions are [1, vocabulary_size]

# %%
embedding_dims = 5
W1 = Variable(torch.randn(embedding_dims, vocabulary_size).float(), requires_grad=True)
W2 = Variable(torch.randn(vocabulary_size, embedding_dims).float(), requires_grad=True)
num_epochs = 101
learning_rate = 0.001

for epo in range(num_epochs):
    loss_val = 0
    for data, target in idx_pairs:
        x = Variable(get_input_layer(data)).float()
        y_true = Variable(torch.from_numpy(np.array([target])).long())

        z1 = torch.matmul(W1, x)
        z2 = torch.matmul(W2, z1)
    
        log_softmax = F.log_softmax(z2, dim=0)

        loss = F.nll_loss(log_softmax.view(1,-1), y_true)
        loss_val += loss.data.item()
        loss.backward()
        W1.data -= learning_rate * W1.grad.data
        W2.data -= learning_rate * W2.grad.data

        W1.grad.data.zero_()
        W2.grad.data.zero_()
    if epo % 10 == 0:    
        print(f'Loss at epo {epo}: {loss_val/len(idx_pairs)}')
# Out:
# Loss at epo 0: 10.166397795444215
# Loss at epo 10: 9.153183325091003
# Loss at epo 20: 8.749699402238075
# Loss at epo 30: 8.50404246508264
# Loss at epo 40: 8.3318158405265
# Loss at epo 50: 8.200809801927916
# Loss at epo 60: 8.095135261678552
# Loss at epo 70: 8.005693760504744
# Loss at epo 80: 7.926830999607039
# Loss at epo 90: 7.854839039072232
# Loss at epo 100: 7.787337587848668

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
def lab1(word):
    index_of_word = -1
    for i in range(len(vocabulary)):
        if  (vocabulary[i] == word):
            index_of_word = i
    if (index_of_word < 0):
        print('This word does not exist on dataset')
    if (index_of_word >= 0):
        print('Index of the word', vocabulary[index_of_word],' is ',index_of_word)
        print('Task 1: Thensors of words')
        print(W2.data)
        cos_distance = []
        labels = []
        aaa = np.array(W2.data)
        for j in range(len(W2)):
            result = np.dot(np.array(aaa[j]),np.array(aaa[index_of_word]))/(((np.sum(aaa[j]**2))**0.5) * ((np.sum(aaa[index_of_word]**2))**0.5))
            cos_distance.append([result, j])
        cos_distance_sorted = sorted(cos_distance, key=lambda x: x[0], reverse=True)
        for i in (range(10)):
            print(cos_distance_sorted[i], vocabulary[cos_distance_sorted[i][1]])
            labels.append(vocabulary[cos_distance_sorted[i][1]])
        array_for_dot_cloud = []
        array_for_dot_cloud_label = []
        for i in range(11):
            array_for_dot_cloud.append(np.array(aaa[cos_distance_sorted[i][1]]))
            array_for_dot_cloud_label.append(vocabulary[cos_distance_sorted[i][1]])
        print(W2[cos_distance_sorted[i][1]], vocabulary[cos_distance_sorted[i][1]])
        array_for_dot_cloud = np.array(array_for_dot_cloud)
        print(array_for_dot_cloud)
        X_embedded = TSNE(n_components=2).fit_transform(array_for_dot_cloud)
        X_embedded.shape
        #print(X_embedded)
        x = []
        y = []
        new_values = X_embedded
        for value in new_values:
            x.append(value[0])
            y.append(value[1])
        plt.figure(figsize=(16, 16)) 
        for i in range(len(x)):
            plt.scatter(x[i],y[i])
            plt.annotate(array_for_dot_cloud_label[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
        plt.show()

# %%
lab1('america')
# Out:
# Index of the word america  is  711
# Task 1: Thensors of words
# tensor([[-0.0288,  1.2831, -0.7223, -0.2003,  0.5829],
#         [-1.0676,  0.2906, -0.4953, -0.4029, -0.3702],
#         [-0.4868,  0.2298,  0.5952,  0.2467,  0.2876],
#         ...,
#         [-0.0854, -0.3742,  0.2183,  0.3730, -0.5833],
#         [-0.3887, -0.7016,  1.1935,  0.1773,  0.1490],
#         [-0.1909,  0.6825,  0.6522,  1.1936, -0.0246]])
# [0.999999893614045, 711] america
# [0.9950152862930665, 510] michael
# [0.9916279678414051, 2432] flying
# [0.9685599589911168, 656] everybody
# [0.9603269217748326, 276] trial
# [0.9479476449001417, 2323] electra
# [0.9441954266230944, 1912] flew
# [0.9389586667152674, 1845] rumours
# [0.9338634306620393, 849] linked
# [0.9317426333394851, 2159] suggested
# tensor([-1.1396, -0.6753,  0.7273, -0.6246, -0.9116], grad_fn=<SelectBackward>) especially
# [[-0.47718245 -0.5478108   0.89045227 -0.41995788 -0.8625557 ]
#  [-0.39078563 -0.5012448   0.8966513  -0.48215953 -0.9705013 ]
#  [-0.3691568  -0.6734373   0.80061907 -0.3727714  -0.7966779 ]
#  [-0.3856577  -0.87690055  1.1633369  -0.6657318  -0.74197155]
#  [-0.34987563 -0.44084427  0.8196468  -0.1322963  -1.1126051 ]
#  [-0.04028708 -0.36140412  0.35872674 -0.19599345 -0.48148918]
#  [-0.36260077 -0.26541966  1.1990722  -0.2154409  -0.7258368 ]
#  [-0.47869614 -0.68984175  1.3569552  -0.39702964 -0.50721765]
#  [-0.06110429 -0.76401466  0.9337787  -0.54106873 -0.62855834]
#  [-0.6959409  -0.07130075  0.9147463  -0.49683937 -0.73098516]
#  [-1.1396344  -0.6753458   0.72728574 -0.6245791  -0.9116075 ]]

# %%
lab1('bbc')
# Out:
# Index of the word bbc  is  566
# Task 1: Thensors of words
# tensor([[-0.0288,  1.2831, -0.7223, -0.2003,  0.5829],
#         [-1.0676,  0.2906, -0.4953, -0.4029, -0.3702],
#         [-0.4868,  0.2298,  0.5952,  0.2467,  0.2876],
#         ...,
#         [-0.0854, -0.3742,  0.2183,  0.3730, -0.5833],
#         [-0.3887, -0.7016,  1.1935,  0.1773,  0.1490],
#         [-0.1909,  0.6825,  0.6522,  1.1936, -0.0246]])
# [1.0, 566] bbc
# [0.986897279714731, 843] needs
# [0.969265153627157, 2123] class
# [0.9449425272608287, 786] memorial
# [0.9394840667555296, 687] earning
# [0.9392223213183335, 39] europe
# [0.9369373359015022, 506] sequels
# [0.9361079018546807, 1602] titles
# [0.9344022184829519, 717] spinal
# [0.930806164184021, 294] historical
# tensor([-0.4842, -1.0813, -0.1966, -0.9789, -0.2148], grad_fn=<SelectBackward>) audiences
# [[-1.4811939  -1.6637567   0.28752375 -1.7265762  -1.0008463 ]
#  [-0.6256267  -0.76174444 -0.07346518 -0.7014876  -0.46488792]
#  [-0.7289824  -0.61830735 -0.03958898 -0.90072536 -0.742626  ]
#  [-0.7132213  -0.7710951   0.20537174 -1.2706138  -0.14141095]
#  [-0.28494456 -0.69646823  0.1275726  -0.3572929  -0.23494941]
#  [-1.2193779  -0.8446468  -0.32630745 -1.3911102  -0.40200517]
#  [-0.5016952  -0.29418218  0.27682143 -0.77014124 -0.39495024]
#  [-0.6827109  -0.684842   -0.2788403  -1.1519897  -0.36047626]
#  [-0.20348445 -0.68657297 -0.00933728 -0.8192243  -0.4505012 ]
#  [-0.9581245  -0.56302    -0.29930362 -0.96558064 -0.44279277]
#  [-0.48419937 -1.0812544  -0.19659175 -0.9789226  -0.21482116]]
